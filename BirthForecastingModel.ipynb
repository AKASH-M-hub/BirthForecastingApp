# %%
# !pip install prophet

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import prophet

# %%
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b41003ee-9c49-456c-a2ec-4d96ce436dda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b41003ee-9c49-456c-a2ec-4d96ce436dda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("daily-total-female-births-CA.csv")

# %%
print(df.head())
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
plt.plot(df["date"],df["births"])
plt.title("Daily female birth in 1959")
# Out:
# Text(0.5, 1.0, 'Daily female birth in 1959')

# %%
df = df.rename(columns={'date': 'ds', 'births': 'y'})
df['ds'] = pd.to_datetime(df['ds'])
with warnings.catch_warnings():
  warnings.simplefilter("ignore")
  m=prophet.Prophet(yearly_seasonality=True,daily_seasonality=False,changepoint_range=0.9,changepoint_prior_scale=0.5,seasonality_mode="multiplicative")
  m.fit(df)
future=m.make_future_dataframe(periods=50,freq="d")
forecast=m.predict(future)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpp_q8o3uv/jo_qp3j5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpp_q8o3uv/4dxwfo4z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88081', 'data', 'file=/tmp/tmpp_q8o3uv/jo_qp3j5.json', 'init=/tmp/tmpp_q8o3uv/4dxwfo4z.json', 'output', 'file=/tmp/tmpp_q8o3uv/prophet_model459zdbsf/prophet_model-20250722043648.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:36:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:36:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
m.plot_components(forecast)

# %%
m.plot(forecast)

# %%
pip install streamlit prophet pandas matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.0 MB/s eta 0:00:00
# ...
